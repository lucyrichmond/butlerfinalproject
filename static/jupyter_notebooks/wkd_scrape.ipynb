# %%
import os
import requests
from bs4 import BeautifulSoup
import pandas as pd
from splinter import Browser
import splinter
import numpy as np

# %%
# create variables to store scraped info
movie_titles = []
opening_amts = []
total_gross = []
per_of_total = []
num_of_theaters = []
open_date = []

# %%
# loop through pages to get data from all 1000 movies 

pages = np.arange(0, 801, 200)

for page in pages:
    page = requests.get('https://www.boxofficemojo.com/chart/top_opening_weekend/?offset=' + str(page))
    
    # Create BeautifulSoup object; parse with 'lxml'
    soup = BeautifulSoup(page.text, 'lxml')
    
    titles = soup.find_all('td', class_ = 'a-text-left mojo-field-type-release mojo-cell-wide')
    for movie in titles:
        movie_titles.append(movie.select('a')[0].string)

    opening = soup.find_all('td', class_ = 'a-text-right mojo-field-type-money')
    for amt in opening:
        opening_amts.append(amt.string)

    total = soup.find_all('td', class_ = 'a-text-right mojo-field-type-money mojo-estimatable')
    for money in total:
        total_gross.append(money.string)

    percent_of_total = soup.find_all('td', class_ = 'a-text-right mojo-field-type-percent')
    for percent in percent_of_total:
        per_of_total.append(percent.string)

    theaters = soup.find_all('td', class_ = 'a-text-right mojo-field-type-positive_integer mojo-estimatable')
    for thr in theaters:
        num_of_theaters.append(thr.string)

    date = soup.find_all('td', class_ = 'a-text-left mojo-field-type-date a-nowrap')
    for day in date:
        open_date.append(day.string)

# %%
gross_df = pd.DataFrame({"Gross & Average": total_gross})

gross_df
# Out:
#      Gross & Average
# 0       $858,373,000
# 1            $76,601
# 2       $678,815,482
# 3            $57,599
# 4       $936,662,225
# ...              ...
# 1995          $8,405
# 1996     $60,240,295
# 1997          $7,454
# 1998     $54,870,175
# 1999          $7,783
#
# [2000 rows x 1 columns]

# %%
# strip punctuation and turn into integer
gross_df['Gross & Average'] = gross_df['Gross & Average'].map(lambda x: x.lstrip('$')).str.replace(',', '').astype(int)


# separate total gross from avg. per theater
avg_thr = gross_df[gross_df['Gross & Average'] < 100000].dropna().reset_index()['Gross & Average']
total_grss = gross_df[gross_df['Gross & Average'] > 100000].dropna().reset_index()['Gross & Average']



gross_df['Total Gross'] = total_grss
gross_df['Average per Theater'] = avg_thr

gross_df = gross_df.drop(columns=['Gross & Average']).dropna()
gross_df['Movie Title'] = movie_titles

gross_df
# Out:
#      Total Gross  Average per Theater  \
# 0    858373000.0              76601.0
# 1    678815482.0              57599.0
# 2    936662225.0              59982.0
# 3    620181382.0              51987.0
# 4    652270625.0              48855.0
# ..           ...                  ...
# 995   50856010.0               6954.0
# 996   48071303.0               6469.0
# 997   42670410.0               8405.0
# 998   60240295.0               7454.0
# 999   54870175.0               7783.0
#
#                                     Movie Title
# 0                             Avengers: Endgame
# 1                        Avengers: Infinity War
# 2    Star Wars: Episode VII - The Force Awakens
# 3       Star Wars: Episode VIII - The Last Jedi
# 4                                Jurassic World
# ..                                          ...
# 995                                       Ouija
# 996                                    Kick-Ass
# 997                                  The Unborn
# 998                               The Cable Guy
# 999                                       Spawn
#
# [1000 rows x 3 columns]

# %%
# create DataFrame
opening_df = pd.DataFrame({"Movie Title": movie_titles, "Opening": opening_amts, "Total Gross": total_grss, "% of Total": per_of_total, "Theaters": num_of_theaters, "Average per Theater": avg_thr, "Date": open_date})
#pd.options.display.float_format = '{:,}'.format

#df['new_column_name'] = df['column_name'].map('{:,.2f}'.format)

#opening_df['Total Gross'] = '$' + (opening_df['Total Gross'].astype(float)).map('{:,.2f}'.format).astype(str)
#opening_df['Average per Theater'] = '$' + (opening_df['Average per Theater'].astype(float)).map('{:,.2f}'.format).astype(str)

opening_df
# Out:
#                                     Movie Title       Opening  Total Gross  \
# 0                             Avengers: Endgame  $357,115,007    858373000
# 1                        Avengers: Infinity War  $257,698,183    678815482
# 2    Star Wars: Episode VII - The Force Awakens  $247,966,675    936662225
# 3       Star Wars: Episode VIII - The Last Jedi  $220,009,584    620181382
# 4                                Jurassic World  $208,806,270    652270625
# ..                                          ...           ...          ...
# 995                                       Ouija   $19,875,995     50856010
# 996                                    Kick-Ass   $19,828,687     48071303
# 997                                  The Unborn   $19,810,585     42670410
# 998                               The Cable Guy   $19,806,226     60240295
# 999                                       Spawn   $19,738,749     54870175
#
#     % of Total Theaters  Average per Theater          Date
# 0        41.6%    4,662                76601  Apr 26, 2019
# 1          38%    4,474                57599  Apr 27, 2018
# 2        26.5%    4,134                59982  Dec 18, 2015
# 3        35.5%    4,232                51987  Dec 15, 2017
# 4          32%    4,274                48855  Jun 12, 2015
# ..         ...      ...                  ...           ...
# 995      39.1%    2,858                 6954  Oct 24, 2014
# 996      41.2%    3,065                 6469  Apr 16, 2010
# 997      46.4%    2,357                 8405   Jan 9, 2009
# 998      32.9%    2,657                 7454  Jun 14, 1996
# 999        36%    2,536                 7783   Aug 1, 1997
#
# [1000 rows x 7 columns]

# %%
# strip punctuation and turn into integer
opening_df['Opening'] = opening_df['Opening'].map(lambda x: x.lstrip('$')).str.replace(',', '').astype(int)
opening_df['Theaters'] = opening_df['Theaters'].str.replace(',', '').astype(int)

opening_df
# Out:
#                                     Movie Title    Opening  Total Gross  \
# 0                             Avengers: Endgame  357115007    858373000
# 1                        Avengers: Infinity War  257698183    678815482
# 2    Star Wars: Episode VII - The Force Awakens  247966675    936662225
# 3       Star Wars: Episode VIII - The Last Jedi  220009584    620181382
# 4                                Jurassic World  208806270    652270625
# ..                                          ...        ...          ...
# 995                                       Ouija   19875995     50856010
# 996                                    Kick-Ass   19828687     48071303
# 997                                  The Unborn   19810585     42670410
# 998                               The Cable Guy   19806226     60240295
# 999                                       Spawn   19738749     54870175
#
#     % of Total  Theaters  Average per Theater          Date
# 0        41.6%      4662                76601  Apr 26, 2019
# 1          38%      4474                57599  Apr 27, 2018
# 2        26.5%      4134                59982  Dec 18, 2015
# 3        35.5%      4232                51987  Dec 15, 2017
# 4          32%      4274                48855  Jun 12, 2015
# ..         ...       ...                  ...           ...
# 995      39.1%      2858                 6954  Oct 24, 2014
# 996      41.2%      3065                 6469  Apr 16, 2010
# 997      46.4%      2357                 8405   Jan 9, 2009
# 998      32.9%      2657                 7454  Jun 14, 1996
# 999        36%      2536                 7783   Aug 1, 1997
#
# [1000 rows x 7 columns]

# %%
import datetime as dt 
opening_df['Date'] = pd.to_datetime(opening_df['Date'])
opening_df
# Out:
#                                     Movie Title    Opening  Total Gross  \
# 0                             Avengers: Endgame  357115007    858373000
# 1                        Avengers: Infinity War  257698183    678815482
# 2    Star Wars: Episode VII - The Force Awakens  247966675    936662225
# 3       Star Wars: Episode VIII - The Last Jedi  220009584    620181382
# 4                                Jurassic World  208806270    652270625
# ..                                          ...        ...          ...
# 995                                       Ouija   19875995     50856010
# 996                                    Kick-Ass   19828687     48071303
# 997                                  The Unborn   19810585     42670410
# 998                               The Cable Guy   19806226     60240295
# 999                                       Spawn   19738749     54870175
#
#     % of Total  Theaters  Average per Theater       Date
# 0        41.6%      4662                76601 2019-04-26
# 1          38%      4474                57599 2018-04-27
# 2        26.5%      4134                59982 2015-12-18
# 3        35.5%      4232                51987 2017-12-15
# 4          32%      4274                48855 2015-06-12
# ..         ...       ...                  ...        ...
# 995      39.1%      2858                 6954 2014-10-24
# 996      41.2%      3065                 6469 2010-04-16
# 997      46.4%      2357                 8405 2009-01-09
# 998      32.9%      2657                 7454 1996-06-14
# 999        36%      2536                 7783 1997-08-01
#
# [1000 rows x 7 columns]

# %%
#month = opening_df['Date'].dt.month
month = opening_df['Date']

opening_df['Season Number'] = (month.dt.month%12 + 3)//3
opening_df
# Out:
#                                     Movie Title    Opening  Total Gross  \
# 0                             Avengers: Endgame  357115007    858373000
# 1                        Avengers: Infinity War  257698183    678815482
# 2    Star Wars: Episode VII - The Force Awakens  247966675    936662225
# 3       Star Wars: Episode VIII - The Last Jedi  220009584    620181382
# 4                                Jurassic World  208806270    652270625
# ..                                          ...        ...          ...
# 995                                       Ouija   19875995     50856010
# 996                                    Kick-Ass   19828687     48071303
# 997                                  The Unborn   19810585     42670410
# 998                               The Cable Guy   19806226     60240295
# 999                                       Spawn   19738749     54870175
#
#     % of Total  Theaters  Average per Theater       Date  Season Number
# 0        41.6%      4662                76601 2019-04-26              2
# 1          38%      4474                57599 2018-04-27              2
# 2        26.5%      4134                59982 2015-12-18              1
# 3        35.5%      4232                51987 2017-12-15              1
# 4          32%      4274                48855 2015-06-12              3
# ..         ...       ...                  ...        ...            ...
# 995      39.1%      2858                 6954 2014-10-24              4
# 996      41.2%      3065                 6469 2010-04-16              2
# 997      46.4%      2357                 8405 2009-01-09              1
# 998      32.9%      2657                 7454 1996-06-14              3
# 999        36%      2536                 7783 1997-08-01              3
#
# [1000 rows x 8 columns]

# %%
year = opening_df['Date'].dt.year
opening_df['Release Year'] = year
opening_df
# Out:
#                                     Movie Title    Opening  Total Gross  \
# 0                             Avengers: Endgame  357115007    858373000
# 1                        Avengers: Infinity War  257698183    678815482
# 2    Star Wars: Episode VII - The Force Awakens  247966675    936662225
# 3       Star Wars: Episode VIII - The Last Jedi  220009584    620181382
# 4                                Jurassic World  208806270    652270625
# ..                                          ...        ...          ...
# 995                                       Ouija   19875995     50856010
# 996                                    Kick-Ass   19828687     48071303
# 997                                  The Unborn   19810585     42670410
# 998                               The Cable Guy   19806226     60240295
# 999                                       Spawn   19738749     54870175
#
#     % of Total  Theaters  Average per Theater       Date  Season Number  \
# 0        41.6%      4662                76601 2019-04-26              2
# 1          38%      4474                57599 2018-04-27              2
# 2        26.5%      4134                59982 2015-12-18              1
# 3        35.5%      4232                51987 2017-12-15              1
# 4          32%      4274                48855 2015-06-12              3
# ..         ...       ...                  ...        ...            ...
# 995      39.1%      2858                 6954 2014-10-24              4
# 996      41.2%      3065                 6469 2010-04-16              2
# 997      46.4%      2357                 8405 2009-01-09              1
# 998      32.9%      2657                 7454 1996-06-14              3
# 999        36%      2536                 7783 1997-08-01              3
#
#      Release Year
# 0            2019
# 1            2018
# 2            2015
# 3            2017
# 4            2015
# ..            ...
# 995          2014
# 996          2010
# 997          2009
# 998          1996
# 999          1997
#
# [1000 rows x 9 columns]

# %%
opening_df["Movie & Year"] = opening_df["Movie Title"] + " " + "(" + opening_df["Release Year"].astype(str) + ")"
opening_df.head()
# Out:
#                                   Movie Title    Opening  Total Gross  \
# 0                           Avengers: Endgame  357115007    858373000
# 1                      Avengers: Infinity War  257698183    678815482
# 2  Star Wars: Episode VII - The Force Awakens  247966675    936662225
# 3     Star Wars: Episode VIII - The Last Jedi  220009584    620181382
# 4                              Jurassic World  208806270    652270625
#
#   % of Total  Theaters  Average per Theater       Date  Season Number  \
# 0      41.6%      4662                76601 2019-04-26              2
# 1        38%      4474                57599 2018-04-27              2
# 2      26.5%      4134                59982 2015-12-18              1
# 3      35.5%      4232                51987 2017-12-15              1
# 4        32%      4274                48855 2015-06-12              3
#
#    Release Year                                       Movie & Year
# 0          2019                           Avengers: Endgame (2019)
# 1          2018                      Avengers: Infinity War (2018)
# 2          2015  Star Wars: Episode VII - The Force Awakens (2015)
# 3          2017     Star Wars: Episode VIII - The Last Jedi (2017)
# 4          2015                              Jurassic World (2015)

# %%
seasons = opening_df['Season Number'].astype(int)

season_name = []

for s in seasons:
    if (s == 1):
        season_name.append('Winter')
    elif (s == 2):
        season_name.append('Spring')
    elif (s == 3):
        season_name.append('Summer')
    elif (s == 4):
        season_name.append('Fall')

season_name
# Out:
# ['Spring',
#  'Spring',
#  'Winter',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Summer']

# %%
opening_df['Season Name'] = season_name

opening_df
# Out:
#                                     Movie Title    Opening  Total Gross  \
# 0                             Avengers: Endgame  357115007    858373000
# 1                        Avengers: Infinity War  257698183    678815482
# 2    Star Wars: Episode VII - The Force Awakens  247966675    936662225
# 3       Star Wars: Episode VIII - The Last Jedi  220009584    620181382
# 4                                Jurassic World  208806270    652270625
# ..                                          ...        ...          ...
# 995                                       Ouija   19875995     50856010
# 996                                    Kick-Ass   19828687     48071303
# 997                                  The Unborn   19810585     42670410
# 998                               The Cable Guy   19806226     60240295
# 999                                       Spawn   19738749     54870175
#
#     % of Total  Theaters  Average per Theater       Date  Season Number  \
# 0        41.6%      4662                76601 2019-04-26              2
# 1          38%      4474                57599 2018-04-27              2
# 2        26.5%      4134                59982 2015-12-18              1
# 3        35.5%      4232                51987 2017-12-15              1
# 4          32%      4274                48855 2015-06-12              3
# ..         ...       ...                  ...        ...            ...
# 995      39.1%      2858                 6954 2014-10-24              4
# 996      41.2%      3065                 6469 2010-04-16              2
# 997      46.4%      2357                 8405 2009-01-09              1
# 998      32.9%      2657                 7454 1996-06-14              3
# 999        36%      2536                 7783 1997-08-01              3
#
#      Release Year                                       Movie & Year  \
# 0            2019                           Avengers: Endgame (2019)
# 1            2018                      Avengers: Infinity War (2018)
# 2            2015  Star Wars: Episode VII - The Force Awakens (2015)
# 3            2017     Star Wars: Episode VIII - The Last Jedi (2017)
# 4            2015                              Jurassic World (2015)
# ..            ...                                                ...
# 995          2014                                       Ouija (2014)
# 996          2010                                    Kick-Ass (2010)
# 997          2009                                  The Unborn (2009)
# 998          1996                               The Cable Guy (1996)
# 999          1997                                       Spawn (1997)
#
#     Season Name
# 0        Spring
# 1        Spring
# 2        Winter
# 3        Winter
# 4        Summer
# ..          ...
# 995        Fall
# 996      Spring
# 997      Winter
# 998      Summer
# 999      Summer
#
# [1000 rows x 11 columns]

# %%
# export to csv
opening_df.to_csv('data/opening.csv')
